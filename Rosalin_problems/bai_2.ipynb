# %%
dna = 'GATGGAACTTGACTACGTAAATT'

# %%
# thay thế T bằng U
rna = dna.replace('T', 'U')
print(rna)
# Out:
# GAUGGAACUUGACUACGUAAAUU

# %%
# thay thế T bằng U có count
rna = dna.replace('T', 'U', count= 4)
print(rna)
# Out:
# GAUGGAACUUGACUACGTAAATT

# %%
dna = '...'

# %%
rna = dna.replace('T','U')
print(rna)
# Out:
# ...

# %%
f = 'AATGC'
r = 'TTACG'
