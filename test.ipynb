# %%
print("hello")
# Out:
# hello

# %%
# %pip install biopython

# %%
import Bio

# %%
# %pip install numpy,pandas,scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: 'numpy,pandas,scipy': Expected end or semicolon (after name and no valid version specifier)
#     numpy,pandas,scipy
#          ^

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scipy
# Out:
# ...
#   Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
